# %%
from airbnb_listings_fetch import fetch_airbnb_listings_by_location, fetch_airbnb_listings_by_url

# Fetch listings by location
snapshot_id, listings_data, listings_df = fetch_airbnb_listings_by_location("Beltline, Calgary", limit_per_input=100)
# Out:
# Fetching Airbnb listings for location: Beltline, Calgary
# Limit per input: 100
# Max wait time: 1800 seconds (~30.0 minutes)
# --------------------------------------------------------------------------------
# Step 1: Triggering BrightData API snapshot...
# ✓ Snapshot triggered successfully. Snapshot ID: s_mhtrcszx11oyucueli
#
# Step 2: Waiting for snapshot to complete (this typically takes 10-15 minutes)...
# Attempt 1/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 2/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 3/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 4/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 5/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 6/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 7/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 8/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 9/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 10/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 11/60: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 12/60: Checking snapshot status...
# Snapshot ready! Data retrieved successfully.
# ✓ Snapshot retrieved successfully
#
# Step 3: Extracting listings data...
# Successfully extracted 100 Airbnb listings
# ✓ Extraction complete
#
# ================================================================================
# Location Listings: Beltline, Calgary
# Total listings retrieved: 100
# Snapshot ID: s_mhtrcszx11oyucueli

# %%
# Save listings data into json file in Resources folder
import json
with open("Resources/airbnb_beltline_calgary_listings_100.json", "w") as json_file:
    json.dump(listings_data, json_file, indent=2)

# Save to excel file in Resources folder
listings_df.to_excel("Resources/airbnb_beltline_calgary_listings_100.xlsx", index=False)

# %%
# Fetch listings from a specific URL
url = "https://www.airbnb.ca/rooms/1300059188064308611"
snapshot_id, listings_data_url, listings_df_url = fetch_airbnb_listings_by_url(url)
# Out:
# Fetching Airbnb listing from URL: https://www.airbnb.ca/rooms/1300059188064308611
# Country: CA
# Max wait time: 300 seconds (~5.0 minutes)
# --------------------------------------------------------------------------------
# Step 1: Triggering BrightData API snapshot...
# ✓ Snapshot triggered successfully. Snapshot ID: s_mhts21kd18dx8xbkbz
#
# Step 2: Waiting for snapshot to complete (this typically takes 2-5 minutes)...
# Attempt 1/10: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 2/10: Checking snapshot status...
# Snapshot still processing (status: running). Waiting 30 seconds...
# Attempt 3/10: Checking snapshot status...
# Snapshot ready! Data retrieved successfully.
# ✓ Snapshot retrieved successfully
#
# Step 3: Extracting listing data...
# Successfully extracted 1 Airbnb listings
# ✓ Extraction complete
#
# ================================================================================
# URL Listing: https://www.airbnb.ca/rooms/1300059188064308611
# Total listings retrieved: 1
# Snapshot ID: s_mhts21kd18dx8xbkbz

# %%
# Save listings data into json file in Resources folder
with open("Resources/airbnb_listing_1300059188064308611.json", "w") as json_file:
    json.dump(listings_data_url, json_file, indent=2)

# Save to excel file in Resources folder
listings_df_url.to_excel("Resources/airbnb_listing_1300059188064308611.xlsx", index=False)

# %% [markdown]
# # Data by location

# %%
import os
from dotenv import load_dotenv
import requests

# Load environment variables
load_dotenv()

brightdata_api_key = os.getenv("BRIGHTDATA_API_KEY")
if not brightdata_api_key:
    raise ValueError("BRIGHTDATA_API_KEY environment variable is required. Please check your .env file.")

# %%
url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
	"Authorization": f"Bearer {brightdata_api_key}",
	"Content-Type": "application/json",
}
params = {
	"dataset_id": "gd_ld7ll037kqy322v05",
	"include_errors": "false",
	"type": "discover_new",
	"discover_by": "location",
	"limit_per_input": "25",
}
data = {
	"input": [{"location":"Beltline, Calgary","currency":"CAD","country":"CA","num_of_infants":""}],
	"custom_output_fields": [
        "name",
        "price",
        # "image",
        "description",
        "category",
        "availability",
        "discount",
        "reviews",
        "ratings",
        # "seller_info",
        # "breadcrumbs",
        "location",
        "lat",
        "long",
        "guests",
        "pets_allowed",
        "description_items",
        "category_rating",
        "house_rules",
        "details",
        "highlights",
        "arrangement_details",
        "amenities",
        # "images",
        # "available_dates",
        "url",
        # "final_url",
        "listing_title",
        "property_id",
        "listing_name",
        "location_details",
        "description_by_sections",
        # "description_html",
        # "location_details_html",
        "is_supperhost",
        "host_number_of_reviews",
        "host_rating",
        "hosts_year",
        "host_response_rate",
        "is_guest_favorite",
        "travel_details",
        "pricing_details",
        "total_price",
        "currency",
        "cancellation_policy",
        "property_number_of_reviews",
        # "country",
        # "postcode_map_url",
        # "host_image",
        "host_details",
        "reviews_details",
        "timestamp",
        # "input",
        # "discovery_input",
        # "error",
        # "error_code",
        # "warning",
        # "warning_code"
        ],
}

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())
# Out:
# {'snapshot_id': 's_mhsejjfk7tspayf1x'}

# %%
import requests
import json

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mhsedqh31wk5tat74s"
headers = {
    "Authorization": f"Bearer {brightdata_api_key}",
}
params = {"format": "json"}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# Pretty-print entire JSON to console
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "name": "Condo in Calgary · ★4.83 · Studio · 1 bed · 1 bath",
#     "price": 84.1,
#     "description": "Welcome! Although there are many great things about this property, location is number one.This basement suite has its own entrance and is set up with anything you could possibly need. Located just 3 short blocks from the 17th ave retail/entertainment district, walking distance from the Stampede Grounds, train station, MNP Centre and many more.Our place has a separate entrance, laundry machine & dryer,  and we don't charge a cleaning fee.One free parking stall in covered garage included.The spaceOur space is clean and private. It is a basement studio sized apartment.Guest accessYou will arrive at the front door that contains a numbered lock and will have been given a code prior to check in. Once inside you will come into a lobby area with two doors-  The door on the right will lead to your suite. Keys for the suite will be hung inside the lobby for you. We ask that you leave your shoes in this area as the stairs down to the suite are carpeted.Other things to notePlease let us know if you need parking and we can send you the instructions right away. There is no air conditioning in this unit but we do have a great tower fan for you, and its in the basement so its cool already!There is a cafe table and patio available to you if you smoke or would like to sit outside!Our home is equipped with a video doorbell to ensure our guests' safety.Registration DetailsBL257269",
#     "category": "Stays",
#     "availability": "true",
#     "reviews": [
#       "Great stay at Taylor and Geoff’s place! Super walkable to restaurants in the Beltline. I opted for street parking in the evenings and had no issues. The value for location and amenities is hard to match! Would stay here again next time I need to be in the Beltline",
#       "Geoff place was a great little stay. Downtown in Calgary near plenty of good restaurants it was easy to get around everywhere! Loved the little map at the front door to give local spots to stop by! Would happily stay there again in the future",
#       "Geoff’s spot was a great place for my wife to stay at an affordable rate. It had a washer and dryer which was helpful and a kitchenette with an air fryer and fridge. The on-site parking was super helpful since parking can get expensive quickly. Overall, pretty good experience",
#       "The perfect little place to bunker down after a long day of exploring.<br/>Everything was clean and tidy and the bed was super comfy!!<br/>There was a bit of noise from upstairs frequently but I guess that makes sense as it is the bottom floor!<br/>Very much enjoyed my stay here.",
#       "We really enjoyed our stay here! Great location, super walkable, and convenient to all of our favorite places. Having the option for off-street parking was a huge plus for us. It’s a great space and we would definitely stay here again!",
#       "Geoff's Airbnb was right in the heart of the city. We were able to leave the car parked up and walk everywhere in the city. The suite was clean and well furnished, with a lovely kitchen with all the amenities you need on a vacation. It was nice and private and clean. Geoff was a great host and always responded. He even gave us a contact number for emergencies at night, so very thoughtful. You may want to bring your earplugs if you want to sleep in. It was quiet at night, but we could hear the people above in the morning.",
#       "Probably the best location to stay in Calgary!!! Within walking distance of downtown (lrt) and 17th .  We parked our vehicle and didn’t have to touch it all weekend.  Just remember it’s a basement suite so don’t expect fabulous views",
#       "What a great find in the heart of downtown Calgary! Easily walkable to anything and everything in the downtown area. Great communication with the hosts who made sure I had everything I needed. Definitely recommend for a solo traveler or couple who wants to be close to all that downtown has to offer.",
#       "A great experience overall. The suite was clean, comfortable, and had everything I needed. The location is super convenient, which made getting around really easy. Geoff and Taylor were incredibly responsive and helpful — communication was seamless throughout. I’d happily stay here again!",
#       "Geoff’s place was clean and matched the description perfectly. Communication was easy and they were very responsive and accommodating to requests. The location is perfect for getting around downtown. Would definitely stay here again and have already booked again for another trip!",
#       "Great stay! Close to all we needed, cozy and great communication from the hosts. It worked great for us!",
#       "Convenient to plenty of restaurants and activities. We were grateful for washer/dryer. Host was very responsive and helpful.",
#       "We appreciated the rate in which our hosts responded. They were quick to address concerns when we brought them to their attention. We had a concern with the bedding but they promptly changed it after we noticed a brown stain on the mattress pad and mattress, and they kindly offered to tackle other cleanliness issues we pointed out. However, we were disappointed with the overall cleanliness of the space upon arrival. There was noticeable buildup on the backsplash, dust caked in the bathroom fan aswell as on baseboards. While the hosts’ efforts to resolve these were appreciated, the initial condition of the property fell short of our expectations for a comfortable stay. If we weren’t pressed for time and alternative accommodations, we likely would not have stayed. We hope these issues can be addressed for future guests, as the hosts’ attentiveness shows their commitment to improving the experience.",
#       "Always a wonderful stay at Geoff’s! He’s incredibly kind, quick to respond, and very flexible. I’ll always choose to stay here whenever it’s available.",
#       "Had everything we needed for a weekend in Calgary. Location was great - near bars, restaurants and other cool sites. I highly recommend!",
#       "The location of Geoff and Taylor's place was incredible and the fact that they offered parking was even more amazing!  The only downside is the lack of natural lighting and fresh air.  The blinds were closed for privacy (totally understandable),  but it would have been nice to be able to open up the window.  Luckily there was a really good fan, so it made for a comfortable night's sleep.  <br/>They were so great with communicating and checking in with me.  I let them know that the sink was draining slowly and that one of the plugs didn't seem to be working, assuring me they would look into it asap.  Any time I had a question they got back to me pretty much right away.<br/>Overall the good definitely outweighed the back and I can't wait to be back!",
#       "Room was okay close to downtown and location where i wanted to go, hosts were responsive and helped out. Would definitely recommend",
#       "Enjoyed the weekend in Calgary at Geoff and Taylor's place. <br/>Great location - we were there for an event at the MNP Center, which is about a 20 minute walk.<br/>Staying here, plus the cooperative weather, saved us on car rental and Uber fares. <br/>Safeway is a short walk away, as is 17th ave, with an amazing selection of restaurants!",
#       "Great spot to stay close to the downtown area, bonus that it has a parking garage available. I wouldn't want to drive anything more than a large SUV though as getting in and out of the parking garage would be tricky...like a 10-point turn if you were driving a large truck lol. A little bit of noise from upstairs but I suppose you expect that in a townhome like this. But otherwise this was a nice no frills stay. Oh and a super comfy mattress!",
#       "Wonderful area and exceptional accommodations. Had a perfect birthday! thanks so much Geoff.",
#       "Check in was super easy, and the place was nice and clean! would go back!",
#       "Lovely tree lined street, walking distance to restaurants and coffeehouses",
#       "Geoff and his wife were so kind and it was the perfect stay! Comfy bed, clean, and walkable distance to a lot! They always responded right away! I would stay again :)",
#       "Great location for walking to restaurants and around the downtown area. Train was close by to get to the zoo as well!"
#     ],
#     "ratings": 4.83,
#     "location": "Calgary, Alberta, Canada",
#     "lat": 51.04184,
#     "long": -114.074,
#     "guests": 2,
#     "pets_allowed": false,
#     "description_items": [
#       "Entire condo",
#       "1 bed",
#       "1 bath"
#     ],
#     "category_rating": [
#       {
#         "name": "Cleanliness",
#         "value": "4.7"
#       },
#       {
#         "name": "Accuracy",
#         "value": "4.9"
#       },
#       {
#         "name": "Check-in",
#         "value": "4.9"
#       },
#       {
#         "name": "Communication",
#         "value": "5.0"
#       },
#       {
#         "name": "Location",
#         "value": "4.8"
#       },
#       {
#         "name": "Value",
#         "value": "4.8"
#       }
#     ],
#     "house_rules": [
#       "Check-in after 3:00 PM",
#       "Checkout before 10:00 AM",
#       "2 guests maximum"
#     ],
#     "details": [
#       "2 guests",
#       "Studio",
#       "1 bed",
#       "1 bath"
#     ],
#     "highlights": [
#       {
#         "name": "Self check-in",
#         "value": "Check yourself in with the keypad."
#       },
#       {
#         "name": "Great location",
#         "value": "Guests who stayed here in the past year loved the location."
#       },
#       {
#         "name": "Park for free",
#         "value": "This is one of the few places in the area with free parking."
#       }
#     ],
#     "amenities": [
#       {
#         "items": [
#           {
#             "value": "SYSTEM_HAIRDRYER",
#             "name": "Hair dryer"
#           },
#           {
#             "value": "SYSTEM_CLEANING_SUPPLIES",
#             "name": "Cleaning products"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Shampoo"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Conditioner"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Body soap"
#           },
#           {
#             "value": "SYSTEM_HOT_WATER",
#             "name": "Hot water"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Shower gel"
#           }
#         ],
#         "group_name": "Bathroom"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_WASHER",
#             "name": "Free washer – In unit"
#           },
#           {
#             "value": "SYSTEM_DRYER",
#             "name": "Free dryer – In unit"
#           },
#           {
#             "value": "Towels, bed sheets, soap, and toilet paper",
#             "name": "Essentials"
#           },
#           {
#             "value": "SYSTEM_HANGERS",
#             "name": "Hangers"
#           },
#           {
#             "value": "SYSTEM_BLANKETS",
#             "name": "Bed linens"
#           },
#           {
#             "value": "SYSTEM_PILLOW",
#             "name": "Extra pillows and blankets"
#           },
#           {
#             "value": "SYSTEM_BLACKOUT_SHADES",
#             "name": "Room-darkening shades"
#           },
#           {
#             "value": "SYSTEM_IRON",
#             "name": "Iron"
#           },
#           {
#             "value": "SYSTEM_WARDROBE",
#             "name": "Clothing storage"
#           }
#         ],
#         "group_name": "Bedroom and laundry"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_TV",
#             "name": "42 inch HDTV with Netflix, premium cable, standard cable"
#           }
#         ],
#         "group_name": "Entertainment"
#       },
#       {
#         "items": [
#           {
#             "value": "Sheets provided",
#             "name": "Pack ’n play/Travel crib - available upon request"
#           }
#         ],
#         "group_name": "Family"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_FAN_PORTABLE",
#             "name": "Portable fans"
#           },
#           {
#             "value": "SYSTEM_THERMOMETER",
#             "name": "Heating"
#           }
#         ],
#         "group_name": "Heating and cooling"
#       },
#       {
#         "items": [
#           {
#             "value": "There is one nest doorbell camera at the entryway of the home for everyone's comfort and security. ",
#             "name": "Exterior security cameras on property"
#           },
#           {
#             "value": "SYSTEM_DETECTOR_SMOKE",
#             "name": "Smoke alarm"
#           },
#           {
#             "value": "SYSTEM_DETECTOR_CO",
#             "name": "Carbon monoxide alarm"
#           },
#           {
#             "value": "SYSTEM_FIRE_EXTINGUISHER",
#             "name": "Fire extinguisher"
#           }
#         ],
#         "group_name": "Home safety"
#       },
#       {
#         "items": [
#           {
#             "value": "Verified by speed test. Stream 4K videos and join video calls on multiple devices.",
#             "name": "Fast wifi – 213 Mbps"
#           },
#           {
#             "value": "In a room with a door",
#             "name": "Dedicated workspace"
#           }
#         ],
#         "group_name": "Internet and office"
#       },
#       {
#         "items": [
#           {
#             "value": "Space where guests can cook their own meals",
#             "name": "Kitchen"
#           },
#           {
#             "value": "SYSTEM_REFRIGERATOR",
#             "name": "Refrigerator"
#           },
#           {
#             "value": "SYSTEM_MICROWAVE",
#             "name": "Microwave"
#           },
#           {
#             "value": "Pots and pans, oil, salt and pepper",
#             "name": "Cooking basics"
#           },
#           {
#             "value": "Bowls, chopsticks, plates, cups, etc.",
#             "name": "Dishes and silverware"
#           },
#           {
#             "value": "SYSTEM_REFRIGERATOR",
#             "name": "Freezer"
#           },
#           {
#             "value": "SYSTEM_OVEN",
#             "name": "Oven"
#           },
#           {
#             "value": "SYSTEM_WATER_KETTLE",
#             "name": "Hot water kettle"
#           },
#           {
#             "value": "SYSTEM_COFFEE_MAKER",
#             "name": "Coffee maker: drip coffee maker, french press"
#           },
#           {
#             "value": "SYSTEM_MAPS_BAR",
#             "name": "Wine glasses"
#           },
#           {
#             "value": "SYSTEM_TOASTER",
#             "name": "Toaster"
#           },
#           {
#             "value": "SYSTEM_BAKING_SHEET",
#             "name": "Baking sheet"
#           },
#           {
#             "value": "SYSTEM_BLENDER",
#             "name": "Blender"
#           },
#           {
#             "value": "SYSTEM_DINING_TABLE",
#             "name": "Dining table"
#           },
#           {
#             "value": "SYSTEM_COFFEE_MAKER",
#             "name": "Coffee"
#           }
#         ],
#         "group_name": "Kitchen and dining"
#       },
#       {
#         "items": [
#           {
#             "value": "Separate street or building entrance",
#             "name": "Private entrance"
#           },
#           {
#             "value": "SYSTEM_LAUNDRY_SERVICE",
#             "name": "Laundromat nearby"
#           }
#         ],
#         "group_name": "Location features"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_PATIO_BALCONY",
#             "name": "Shared patio or balcony"
#           },
#           {
#             "value": "An open space on the property usually covered in grass",
#             "name": "Shared backyard"
#           },
#           {
#             "value": "SYSTEM_ROOFTOP_DECK",
#             "name": "Outdoor furniture"
#           }
#         ],
#         "group_name": "Outdoor"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Free parking on premises"
#           },
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Free street parking"
#           },
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Paid street parking off premises"
#           }
#         ],
#         "group_name": "Parking and facilities"
#       },
#       {
#         "items": [
#           {
#             "value": "For guests' convenience when they have early arrival or late departure",
#             "name": "Luggage dropoff allowed"
#           },
#           {
#             "value": "SYSTEM_KEY",
#             "name": "Self check-in"
#           },
#           {
#             "value": "Check yourself into the home with a door code",
#             "name": "Keypad"
#           }
#         ],
#         "group_name": "Services"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_NO_AIR_CONDITIONING",
#             "name": "Air conditioning"
#           }
#         ],
#         "group_name": "Not included"
#       }
#     ],
#     "url": "https://www.airbnb.com/rooms/640067534700391834?search_mode=regular_search&previous_page_section_name=1000&locale=en&currency=CAD",
#     "listing_title": "Urban Beltline Suite near 17th ave + parking",
#     "property_id": "640067534700391834",
#     "listing_name": "Entire condo in Calgary, Canada",
#     "location_details": [
#       {
#         "title": "Neighborhood highlights",
#         "value": "Our neighbourhood is considered Connaught or the Beltline area. Connaught being the community and the Beltline being the general area. The Beltline area is basically a rectangle. A few blocks north is downtown, a few blocks south is 17th ave which is where a lot of the bars and pubs are. To the east you have the Stampede grounds and the confluence of our two beautiful rivers. Our location is as central as you can get in Calgary!"
#       },
#       {
#         "title": "Getting around",
#         "value": "For longer distances (elbow river, river walk, east village, eau claire market) we would recommend taking an e-scooter to get there.There is also lots of public transportation nearby - including the c-train on 7th avenue.We would recommend Uber to get to and from the airport as well."
#       }
#     ],
#     "description_by_sections": [
#       {
#         "title": null,
#         "value": "Welcome! Although there are many great things about this property, location is number one.This basement suite has its own entrance and is set up with anything you could possibly need. Located just 3 short blocks from the 17th ave retail/entertainment district, walking distance from the Stampede Grounds, train station, MNP Centre and many more.Our place has a separate entrance, laundry machine & dryer,  and we don't charge a cleaning fee.One free parking stall in covered garage included."
#       },
#       {
#         "title": "The space",
#         "value": "Our space is clean and private. It is a basement studio sized apartment."
#       },
#       {
#         "title": "Guest access",
#         "value": "You will arrive at the front door that contains a numbered lock and will have been given a code prior to check in. Once inside you will come into a lobby area with two doors-  The door on the right will lead to your suite. Keys for the suite will be hung inside the lobby for you. We ask that you leave your shoes in this area as the stairs down to the suite are carpeted."
#       },
#       {
#         "title": "Other things to note",
#         "value": "Please let us know if you need parking and we can send you the instructions right away. There is no air conditioning in this unit but we do have a great tower fan for you, and its in the basement so its cool already!There is a cafe table and patio available to you if you smoke or would like to sit outside!Our home is equipped with a video doorbell to ensure our guests' safety."
#       },
#       {
#         "title": "Registration Details",
#         "value": "BL257269"
#       }
#     ],
#     "is_supperhost": true,
#     "host_number_of_reviews": 3579,
#     "host_rating": 4.8,
#     "hosts_year": 9,
#     "host_response_rate": 100,
#     "is_guest_favorite": false,
#     "travel_details": {
#       "check_in": null,
#       "check_out": null,
#       "num_of_adults": null,
#       "num_of_children": null,
#       "num_of_infants": null,
#       "num_of_pets": null
#     },
#     "pricing_details": {
#       "num_of_nights": 2,
#       "initial_price_per_night": 84.1,
#       "price_per_night": 84.1,
#       "price_without_fees": 168.19,
#       "special_offer": null,
#       "cleaning_fee": null,
#       "airbnb_service_fee": null,
#       "taxes": null
#     },
#     "total_price": 182.98,
#     "currency": "CAD",
#     "cancellation_policy": [
#       {
#         "cancellation_name": "Full refund",
#         "cancellation_value": "11/11/2025"
#       },
#       {
#         "cancellation_name": "Partial refund",
#         "cancellation_value": "11/16/2025"
#       }
#     ],
#     "property_number_of_reviews": 266,
#     "host_details": {
#       "name": "Geoff",
#       "host_id": "127455882",
#       "url": "https://www.airbnb.com/users/show/127455882",
#       "image": "https://a0.muscache.com/im/pictures/user/29bc65f0-44ef-43aa-9137-b1516702efa9.jpg",
#       "reviews": 3579,
#       "rating": 4.8,
#       "years_hosting": 9,
#       "response_rate": "Response rate: 100%",
#       "response_time": "Responds within an hour",
#       "my_work": "Bottlescrew Bill's Pub",
#       "languages": null
#     },
#     "reviews_details": [
#       {
#         "review_date": "2025-10-31T22:52:30Z",
#         "rating": 5,
#         "guest_name": "Lauren",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Fernie, Canada",
#         "review": "Great stay at Taylor and Geoff’s place! Super walkable to restaurants in the Beltline. I opted for street parking in the evenings and had no issues. The value for location and amenities is hard to match! Would stay here again next time I need to be in the Beltline",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-21T21:27:57Z",
#         "rating": 5,
#         "guest_name": "Cameron",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "United Kingdom",
#         "review": "Geoff place was a great little stay. Downtown in Calgary near plenty of good restaurants it was easy to get around everywhere! Loved the little map at the front door to give local spots to stop by! Would happily stay there again in the future",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-30T21:44:04Z",
#         "rating": 5,
#         "guest_name": "Ahren",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Charlotte, North Carolina",
#         "review": "Geoff’s spot was a great place for my wife to stay at an affordable rate. It had a washer and dryer which was helpful and a kitchenette with an air fryer and fridge. The on-site parking was super helpful since parking can get expensive quickly. Overall, pretty good experience",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-26T21:00:08Z",
#         "rating": 5,
#         "guest_name": "Charlotte",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "3 years on Airbnb",
#         "review": "The perfect little place to bunker down after a long day of exploring.<br/>Everything was clean and tidy and the bed was super comfy!!<br/>There was a bit of noise from upstairs frequently but I guess that makes sense as it is the bottom floor!<br/>Very much enjoyed my stay here.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-18T22:30:38Z",
#         "rating": 5,
#         "guest_name": "Kendal",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Greensboro, North Carolina",
#         "review": "We really enjoyed our stay here! Great location, super walkable, and convenient to all of our favorite places. Having the option for off-street parking was a huge plus for us. It’s a great space and we would definitely stay here again!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-01T20:02:27Z",
#         "rating": 4,
#         "guest_name": "Leanne",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Nanaimo, Canada",
#         "review": "Geoff's Airbnb was right in the heart of the city. We were able to leave the car parked up and walk everywhere in the city. The suite was clean and well furnished, with a lovely kitchen with all the amenities you need on a vacation. It was nice and private and clean. Geoff was a great host and always responded. He even gave us a contact number for emergencies at night, so very thoughtful. You may want to bring your earplugs if you want to sleep in. It was quiet at night, but we could hear the people above in the morning.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-17T22:48:00Z",
#         "rating": 5,
#         "guest_name": "Mike",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Creston, Canada",
#         "review": "Probably the best location to stay in Calgary!!! Within walking distance of downtown (lrt) and 17th .  We parked our vehicle and didn’t have to touch it all weekend.  Just remember it’s a basement suite so don’t expect fabulous views",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-05-31T22:24:51Z",
#         "rating": 5,
#         "guest_name": "Rhiannon",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Houston, Texas",
#         "review": "What a great find in the heart of downtown Calgary! Easily walkable to anything and everything in the downtown area. Great communication with the hosts who made sure I had everything I needed. Definitely recommend for a solo traveler or couple who wants to be close to all that downtown has to offer.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-08T21:32:20Z",
#         "rating": 5,
#         "guest_name": "Michelle",
#         "stayed_for": "Stayed about a week",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "A great experience overall. The suite was clean, comfortable, and had everything I needed. The location is super convenient, which made getting around really easy. Geoff and Taylor were incredibly responsive and helpful — communication was seamless throughout. I’d happily stay here again!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-05-19T19:51:28Z",
#         "rating": 5,
#         "guest_name": "Corina",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Saint Brides, Canada",
#         "review": "Geoff’s place was clean and matched the description perfectly. Communication was easy and they were very responsive and accommodating to requests. The location is perfect for getting around downtown. Would definitely stay here again and have already booked again for another trip!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-27T19:18:54Z",
#         "rating": 5,
#         "guest_name": "Fane",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Great stay! Close to all we needed, cozy and great communication from the hosts. It worked great for us!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-06T20:53:33Z",
#         "rating": 5,
#         "guest_name": "Ashley",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Knoxville, Tennessee",
#         "review": "Convenient to plenty of restaurants and activities. We were grateful for washer/dryer. Host was very responsive and helpful.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-14T22:14:20Z",
#         "rating": 3,
#         "guest_name": "Kiki",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Red Deer, Canada",
#         "review": "We appreciated the rate in which our hosts responded. They were quick to address concerns when we brought them to their attention. We had a concern with the bedding but they promptly changed it after we noticed a brown stain on the mattress pad and mattress, and they kindly offered to tackle other cleanliness issues we pointed out. However, we were disappointed with the overall cleanliness of the space upon arrival. There was noticeable buildup on the backsplash, dust caked in the bathroom fan aswell as on baseboards. While the hosts’ efforts to resolve these were appreciated, the initial condition of the property fell short of our expectations for a comfortable stay. If we weren’t pressed for time and alternative accommodations, we likely would not have stayed. We hope these issues can be addressed for future guests, as the hosts’ attentiveness shows their commitment to improving the experience.",
#         "host_response": "Thank you for acknowledging our quick response and willingness to assist. However, your review overstates the issues.<br/>The home was professionally cleaned before check-in, and there is no cleaning fee to stay at our place - likely a large factor in your decision to book here. You noted a minor stain, which we immediately addressed, and we offered to reclean any areas of concern. Every request was handled promptly and respectfully.<br/>Citing dust on a bathroom ceiling fan—an out-of-reach fixture not typically inspected daily—as a sign of poor cleanliness is simply unreasonable. We welcome fair, constructive feedback, but we also stand by the quality and service that so many guests consistently recognize.<br/>We encourage future guests to approach stays with reasonable expectations and to review our many positive ratings for a more accurate picture of the experience."
#       },
#       {
#         "review_date": "2025-09-12T19:39:08Z",
#         "rating": 5,
#         "guest_name": "Charleen",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Vancouver, Canada",
#         "review": "Always a wonderful stay at Geoff’s! He’s incredibly kind, quick to respond, and very flexible. I’ll always choose to stay here whenever it’s available.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-07T19:31:07Z",
#         "rating": 5,
#         "guest_name": "Patricia",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Montreal, Canada",
#         "review": "Had everything we needed for a weekend in Calgary. Location was great - near bars, restaurants and other cool sites. I highly recommend!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-30T19:24:42Z",
#         "rating": 4,
#         "guest_name": "Marion",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "11 years on Airbnb",
#         "review": "The location of Geoff and Taylor's place was incredible and the fact that they offered parking was even more amazing!  The only downside is the lack of natural lighting and fresh air.  The blinds were closed for privacy (totally understandable),  but it would have been nice to be able to open up the window.  Luckily there was a really good fan, so it made for a comfortable night's sleep.  <br/>They were so great with communicating and checking in with me.  I let them know that the sink was draining slowly and that one of the plugs didn't seem to be working, assuring me they would look into it asap.  Any time I had a question they got back to me pretty much right away.<br/>Overall the good definitely outweighed the back and I can't wait to be back!",
#         "host_response": "hey thanks so much for the feedback! There is a step stool to open all 3 blinds to the windows, and the window opens as well. Come back anytime!"
#       },
#       {
#         "review_date": "2025-08-24T19:46:16Z",
#         "rating": 4,
#         "guest_name": "Esoheosa",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "2 years on Airbnb",
#         "review": "Room was okay close to downtown and location where i wanted to go, hosts were responsive and helped out. Would definitely recommend",
#         "host_response": null
#       },
#       {
#         "review_date": "2024-12-15T20:23:12Z",
#         "rating": 5,
#         "guest_name": "Erin",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Winnipeg, Canada",
#         "review": "Enjoyed the weekend in Calgary at Geoff and Taylor's place. <br/>Great location - we were there for an event at the MNP Center, which is about a 20 minute walk.<br/>Staying here, plus the cooperative weather, saved us on car rental and Uber fares. <br/>Safeway is a short walk away, as is 17th ave, with an amazing selection of restaurants!",
#         "host_response": null
#       },
#       {
#         "review_date": "2024-11-11T21:07:53Z",
#         "rating": 5,
#         "guest_name": "Stephanie",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "High Prairie, Canada",
#         "review": "Great spot to stay close to the downtown area, bonus that it has a parking garage available. I wouldn't want to drive anything more than a large SUV though as getting in and out of the parking garage would be tricky...like a 10-point turn if you were driving a large truck lol. A little bit of noise from upstairs but I suppose you expect that in a townhome like this. But otherwise this was a nice no frills stay. Oh and a super comfy mattress!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-11-02T23:48:33Z",
#         "rating": 5,
#         "guest_name": "Zi",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Calgary, Canada",
#         "review": "Wonderful area and exceptional accommodations. Had a perfect birthday! thanks so much Geoff.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-19T19:37:06Z",
#         "rating": 5,
#         "guest_name": "Andrew",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "1 month on Airbnb",
#         "review": "Check in was super easy, and the place was nice and clean! would go back!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-20T22:43:04Z",
#         "rating": 4,
#         "guest_name": "Colin",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "10 years on Airbnb",
#         "review": "Lovely tree lined street, walking distance to restaurants and coffeehouses",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-29T22:18:37Z",
#         "rating": 5,
#         "guest_name": "Hope",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Kelowna, Canada",
#         "review": "Geoff and his wife were so kind and it was the perfect stay! Comfy bed, clean, and walkable distance to a lot! They always responded right away! I would stay again :)",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-27T19:38:26Z",
#         "rating": 5,
#         "guest_name": "Julia",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "9 years on Airbnb",
#         "review": "Great location for walking to restaurants and around the downtown area. Train was close by to get to the zoo as well!",
#         "host_response": null
#       }
#     ],
#     "timestamp": "2025-11-10T00:23:05.835Z"
#   },
#   {
#     "name": "Rental unit in Calgary · ★4.97 · 2 bedrooms · 2 beds · 1 bath",
#     "price": 302.31,
#     "description": "Perched on the 20th floor, this sleek 2‑bedroom corner suite delivers panoramic city skyline views through floor‑to‑ceiling windows. Just three blocks from the Stampede Grounds and steps from the dining, nightlife, and shopping along 17th Ave, Stephen Avenue, and First Street, you’ll be immersed in Beltline energy. When you’re ready to explore beyond downtown, scenic river pathways or road trips to Banff and Drumheller await.The spaceOpen Concept Living: Bright kitchen stocked for basic cooking flows into a spacious dining and living area, complete with a dedicated workstation.Bedroom One: Queen‑size bed with sumptuous linens and two large sliding doors for an airy, expansive feel.Bedroom Two: Flexible twin‑to‑king bed setup—let us know your preference when booking. No windows if you like it nice and dark.Bathroom: Full‑size with shower, deep tub, toilet, and sink.Iconic Windows: Enjoy uninterrupted skyline and sunrise vistas from every main living space.Parking: One secure underground stall is included.Guest accessEntire Suite: Enjoy complete privacy in your corner apartment.Rooftop Oasis: Shared access to the vibrant rooftop patio—featuring colourful sunbrellas, raised gardens, and lounging areas perfect for city views.Other things to note*Review house rules before booking*Please message us upon booking—we'd love to know what brings you to Calgary and who will be staying. We are happy to answer any questions and provide personalized recommendations for your stay!IG handle: @birdstone.nestsYour Beltline adventure starts here—book now for the ultimate Calgary skyline experience!Registration DetailsBL274687",
#     "category": "Stays",
#     "availability": "true",
#     "reviews": [
#       "Beautiful apartment with a great location but there is a lot of monitoring. We were told about the door cam watching for “extra guests” but there’s also sound detector inside the apartment and it felt like we were being watched. When we unplugged the modem to plug it directly into our laptop we were immediately messaged to plug it back in and it made us feel extremely uncomfortable.",
#       "This was a fantastic stay! Our hosts, Richard and Teresa, were incredibly welcoming and made us feel right at home. The room was very comfortable and clean, with all the necessary amenities. A particular highlight was the stunning city view from the property. It was breathtaking both during the day and at night. Highly recommended!",
#       "Richard & Teresa’s Airbnb was absolutely perfect for our trip. It is located in a prime location with many restaurants, coffee shops, bakeries and a food hall right across the street. We enjoyed being able to walk across the street and enjoy a meal or pickup a coffee. This unit has the most amazing view of the Calgary skyline that lit up at night. The unit was cozy, clean and set up very intentionally to ensure that guests have everything they need. They included multiple amenities from the in unit laundry to the complimentary snacks and drinks. We were very pleased with the space as well as the underground parking. We would definitely recommend this place to others and would definitely stay again :)",
#       "I had a truly wonderful stay! The host was incredibly friendly and attentive, making me feel right at home. There was an abundance of activities to enjoy, ensuring that my time there was both relaxing and engaging.",
#       "We had a wonderful time. Richard and Teresa made our day when they left a thoughtful gift since it was my husband's birthday when we checked in. They communicated well and were helpful throughout our stay.",
#       "Richard & Teresa’s place was clean, comfortable and very cozy. We got in late in which I really appreciate them understanding. We were welcomed with complimentary snacks which were very handy. It was nice to have coffee and creamer at the airbnb. There were also a few other things I noticed that would be handy if a person stayed longer; spices, cooking oil and vinaigrettes. The beds and pillows were so comfortable. We just all in all had a great stay. The view and the lights at night are absolutely beautiful!",
#       "Was an amazing stay in this lovely appartement with this unique amazing view over Calgary downtown. Will ever come back next time I‘im in Calgary. Thanks a lot for this opportunity.",
#       "The place is in a great location, endless dinning options. We loved the view. The detailed check in instructions were perfect. We would stay again.",
#       "Amazing stay here would definitely recommend to others and would love to stay here again! Super walkable to Everything downtown!! Awesome to relax on the belcony too",
#       "I stayed at this Airbnb in Calgary for six nights, and it was a fantastic experience! The place was clean, tidy, and very comfortable. It was also well-equipped with everything I needed for my stay. The host was incredibly friendly and welcoming, which made the experience even better. The views were amazing, making my time there truly enjoyable. I highly recommend this place to anyone looking for a great stay in Calgary!",
#       "Absolutely Loved my two week stay.  So many close restaurants, definitely try Native Tongues for Mexican and Actually Pretty Good for Pizza (First Street Market).  The views, in the evening, from the Airbnb are gorgeous.  The bed is super comfy with lots of pillow options.  The couch is cozy to tuck in and relax.  Overall, 10/10 and will definitely be booking again",
#       "Was a really beautiful place in such a good location with lots of restaurants, bars and stores nearby.",
#       "Great place to stay with our 10 month old. Easy check in & close to many amenities. Thanks Richard & Teresa!",
#       "They were great! Made accommodations though our flight got in late and the instructions and check in was seamless. Also beautiful view and close to lots with great walking distance to lots",
#       "Top notch location, views and comfort. <br/>We are locals and needed a place while we had some home renovations, the beltline is one of the bast locations in the city. Great food and entertainment right outside your door and you can’t beat the skyline view and sunrise from this corner apartment. <br/>The couch and beds were comfortable, stocked with most things you’d need during a visit. The hosts were very responsive and accommodating. <br/>Absolutely recommend staying here.",
#       "Such a beautiful bnb. The views were breathtaking 😍. Richard and Teresa were great hosts and were very communicative. Would definitely choose to stay here again and recommend it to others as well.",
#       "Awesome Spot! beautiful views and lots of great restaurants downstairs",
#       "Perfect location, stunning views, and beautiful decor. The place was very well stocked with plenty of dishes and utensils. Exceeded our expectations!",
#       "Richard is a fantastic host<br/>Great location surrounded by resturants<br/>The rooms view was amazing<br/>10/10 will be booking again",
#       "Would stay here again in a heartbeat!  The view was INCREDIBLE!  The city lights at night were fabulous!",
#       "Richard and Teresa are exactly what Air BnB hosts should be -- responsive, professional, kind, and go the extra mile to provide lovely touches such as welcome snacks, coffee and tea stocks, and kitchen basics like oil and spices. <br/>We were so fortunate to find this AirBnB, and we would book again unreservedly. Richard and Teresa were extremely kind hosts, and very generous with our Christmas Day checkout. <br/>The unit itself is exactly like the photos and as described. The views are absolutely amazing, and it is both relaxing and awe-inspiring to just sit and look at the city lights in the evening. The decor is top notch, and well thought out. Homey touches such as curated DVDs, games, and books make this a true city retreat. <br/>Having underground parking and an elevator made it accessible to people with more limited mobility, and was super important to us. <br/>This was the perfect location for our last minute visit, and we felt so kindly accommodated by Richard and Teresa.  Thank you again",
#       "Excellent cozy place in Calgary with amazing skyline views. Great location and very comfortable. Communicative and helpful hosts. Highly recommended!",
#       "Amazing views !",
#       "Was a very nice place to stay and host was great with instructions and replying."
#     ],
#     "ratings": 4.97,
#     "location": "Calgary, Alberta, Canada",
#     "lat": 51.0404,
#     "long": -114.0656,
#     "guests": 4,
#     "pets_allowed": false,
#     "description_items": [
#       "Entire rental unit",
#       "2 beds",
#       "1 bath"
#     ],
#     "category_rating": [
#       {
#         "name": "Cleanliness",
#         "value": "4.9"
#       },
#       {
#         "name": "Accuracy",
#         "value": "5.0"
#       },
#       {
#         "name": "Check-in",
#         "value": "5.0"
#       },
#       {
#         "name": "Communication",
#         "value": "5.0"
#       },
#       {
#         "name": "Location",
#         "value": "5.0"
#       },
#       {
#         "name": "Value",
#         "value": "4.9"
#       }
#     ],
#     "house_rules": [
#       "Check-in: 4:00 PM - 10:00 PM",
#       "Checkout before 11:00 AM",
#       "4 guests maximum"
#     ],
#     "details": [
#       "4 guests",
#       "2 bedrooms",
#       "2 beds",
#       "1 bath"
#     ],
#     "highlights": [
#       {
#         "name": "Self check-in",
#         "value": "Check yourself in with the smartlock."
#       },
#       {
#         "name": "Comfy bed for better sleep",
#         "value": "The room-darkening shades and extra bedding are loved by guests."
#       },
#       {
#         "name": "Beautiful and walkable",
#         "value": "Guests say this area is scenic and it’s easy to get around."
#       }
#     ],
#     "arrangement_details": [
#       {
#         "name": "Bedroom 1",
#         "value": "1 queen bed"
#       },
#       {
#         "name": "Bedroom 2",
#         "value": "1 king bed, 1 crib"
#       },
#       {
#         "name": "Living room",
#         "value": "1 couch"
#       }
#     ],
#     "amenities": [
#       {
#         "items": [
#           {
#             "value": "SYSTEM_VIEW_CITY",
#             "name": "City skyline view"
#           },
#           {
#             "value": "SYSTEM_POOL",
#             "name": "Pool view"
#           }
#         ],
#         "group_name": "Scenic views"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_BATHTUB",
#             "name": "Bathtub"
#           },
#           {
#             "value": "SYSTEM_HAIRDRYER",
#             "name": "Hair dryer"
#           },
#           {
#             "value": "SYSTEM_CLEANING_SUPPLIES",
#             "name": "Cleaning products"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Tresemme shampoo"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Tresemme conditioner"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Tresemme body soap"
#           },
#           {
#             "value": "SYSTEM_HOT_WATER",
#             "name": "Hot water"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Shower gel"
#           }
#         ],
#         "group_name": "Bathroom"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_WASHER",
#             "name": "Free washer – In unit"
#           },
#           {
#             "value": "SYSTEM_DRYER",
#             "name": "Free dryer – In unit"
#           },
#           {
#             "value": "Towels, bed sheets, soap, and toilet paper",
#             "name": "Essentials"
#           },
#           {
#             "value": "SYSTEM_HANGERS",
#             "name": "Hangers"
#           },
#           {
#             "value": "Egyptian cotton linens",
#             "name": "Bed linens"
#           },
#           {
#             "value": "SYSTEM_PILLOW",
#             "name": "Extra pillows and blankets"
#           },
#           {
#             "value": "SYSTEM_BLACKOUT_SHADES",
#             "name": "Room-darkening shades"
#           },
#           {
#             "value": "SYSTEM_WARDROBE",
#             "name": "Clothing storage: closet"
#           }
#         ],
#         "group_name": "Bedroom and laundry"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_CABLE",
#             "name": "Ethernet connection"
#           },
#           {
#             "value": "SYSTEM_TV",
#             "name": "50 inch HDTV with Roku"
#           },
#           {
#             "value": "SYSTEM_POOL_TABLE",
#             "name": "Pool table"
#           },
#           {
#             "value": "SYSTEM_BOOK",
#             "name": "Books and reading material"
#           }
#         ],
#         "group_name": "Entertainment"
#       },
#       {
#         "items": [
#           {
# ...
#             "value": "SYSTEM_LAUNDRY_SERVICE",
#             "name": "Laundromat nearby"
#           }
#         ],
#         "group_name": "Location features"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_PATIO_BALCONY",
#             "name": "Private patio or balcony"
#           }
#         ],
#         "group_name": "Outdoor"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Free street parking"
#           },
#           {
#             "value": "Available from Jun to Aug, open from 9:00 AM to 10:00 PM",
#             "name": "Shared outdoor pool - available seasonally, open specific hours, rooftop"
#           },
#           {
#             "value": "The home or building has an elevator that’s at least 52 inches deep and a doorway at least 32 inches wide",
#             "name": "Elevator"
#           },
#           {
#             "value": "SYSTEM_GYM",
#             "name": "Shared gym in building"
#           },
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Paid parking lot off premises"
#           },
#           {
#             "value": "No stairs in home",
#             "name": "Single level home"
#           }
#         ],
#         "group_name": "Parking and facilities"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_KEY",
#             "name": "Self check-in"
#           },
#           {
#             "value": "Check yourself into the home with a door code",
#             "name": "Keypad"
#           },
#           {
#             "value": "SYSTEM_CLEAN",
#             "name": "Cleaning available during stay"
#           }
#         ],
#         "group_name": "Services"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_NO_SURVEILLANCE",
#             "name": "Exterior security cameras on property"
#           }
#         ],
#         "group_name": "Not included"
#       }
#     ],
#     "url": "https://www.airbnb.com/rooms/854771867335722256?search_mode=regular_search&previous_page_section_name=1000&locale=en&currency=CAD",
#     "listing_title": "Elegant • Comfortable Suite w/ Incredible DT View!",
#     "property_id": "854771867335722256",
#     "listing_name": "Entire condo in Calgary, Canada",
#     "location_details": [
#       {
#         "title": "Getting around",
#         "value": "8 minute walk to the nearest LRT station to get you anywhere you need to be in the city. 10th avenue goes directly onto two major highways (Macleod trail and Crowchild Trail). 7 minute walk to 17th avenue, Calgary number one hotspot for bars, restaurants and nightlife. Tons of street parking"
#       }
#     ],
#     "description_by_sections": [
#       {
#         "title": null,
#         "value": "Welcome to this beautifully designed one bed one bath condo located in the heart of downtown Calgary, where industrial style meets comfort and elegance. This stunning condo boasts incredible views of the city skyline, with the iconic Calgary Tower standing tall in the distance."
#       },
#       {
#         "title": "The space",
#         "value": "As you enter the condo, you'll be greeted by an open concept living space that seamlessly blends modern and industrial elements. Exposed and high concrete ceilings create a chic and edgy atmosphere that is softened by the warm, earthy tones of the furnishings.The living room is furnished with a comfortable sofa,  perfect for lounging and enjoying the stunning views of the city through the floor-to-ceiling windows. The sleek and modern kitchen is fully equipped with stainless steel appliances, and all the essentials needed to cook a gourmet meal.The bedroom is a cozy retreat, featuring a plush queen-sized bed with luxurious linens and plenty of storage space in the built-in closet. The bathroom is stylishly designed with a deep bath tub, contemporary fixtures, and plenty of soft towels.This condo also features a private balcony, where you can sit back and relax while taking in the breathtaking views of the city. Other amenities include air conditioning, high-speed internet, and a smart TV for your entertainment needs.Located in the heart of downtown Calgary, this condo is just steps away from some of the city's best restaurants, bars, and shops. Whether you're here for work or play, this industrial-style condo offers the perfect combination of comfort, convenience, and style."
#       },
#       {
#         "title": "Guest access",
#         "value": "Guests will have access to the entire suite plus Sky lounge/ fitness facility and pool"
#       },
#       {
#         "title": "Registration Details",
#         "value": "BL267402"
#       }
#     ],
#     "is_supperhost": false,
#     "host_number_of_reviews": 2217,
#     "host_rating": 4.67,
#     "hosts_year": 4,
#     "host_response_rate": 100,
#     "is_guest_favorite": false,
#     "travel_details": {
#       "check_in": null,
#       "check_out": null,
#       "num_of_adults": null,
#       "num_of_children": null,
#       "num_of_infants": null,
#       "num_of_pets": null
#     },
#     "pricing_details": {
#       "num_of_nights": 1,
#       "initial_price_per_night": 166.7,
#       "price_per_night": 166.7,
#       "price_without_fees": 166.7,
#       "special_offer": null,
#       "cleaning_fee": null,
#       "airbnb_service_fee": null,
#       "taxes": null
#     },
#     "total_price": 181.3,
#     "currency": "CAD",
#     "cancellation_policy": [
#       {
#         "cancellation_name": "No refund",
#         "cancellation_value": "11/09/2026"
#       }
#     ],
#     "property_number_of_reviews": 142,
#     "host_details": {
#       "name": "Tommy",
#       "host_id": "444525312",
#       "url": "https://www.airbnb.com/users/show/444525312",
#       "image": "https://a0.muscache.com/im/pictures/user/User/original/a37722a3-203d-4564-bda4-5c392b3fd02a.jpeg",
#       "reviews": 2217,
#       "rating": 4.67,
#       "years_hosting": 4,
#       "response_rate": "Response rate: 100%",
#       "response_time": "They typically respond within an hour",
#       "my_work": null,
#       "languages": "Speaks Arabic, English, German, and Portuguese"
#     },
#     "reviews_details": [
#       {
#         "review_date": "2025-09-14T22:03:25Z",
#         "rating": 5,
#         "guest_name": "Travis",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Medicine Hat, Canada",
#         "review": "Clean place , amazing view and easy check in. Was al perfect lititle spot for our trip. If I could have changed one thing it was I didn’t realizie that the undergoing parking was not included and I didn’t like leaving my car on the street.  Other then that everything was great",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-02-17T22:14:25Z",
#         "rating": 1,
#         "guest_name": "Harsimran",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "1 year on Airbnb",
#         "review": "Booked this BnB for a nice quiet gateway. The room was not so clean, had debris and dirt over the floors. The view was the only outstanding part of the apartment. We hardly got any sleep in due to the party happening. The closest was pre-broken when we got to the bnb, definitely does not match the pictures. I wouldn’t book again if I was looking for comfort. I will definitely book for the view. The communication between the host was smooth.",
#         "host_response": null
#       },
#       {
#         "review_date": "2024-12-29T23:55:03Z",
#         "rating": 5,
#         "guest_name": "Mark",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "North Vancouver, Canada",
#         "review": "I had a fantastic stay here. The location is amazing - clear views of the Calgary tower from all areas of the condo. <br/>The unit was clean, and communication from the hosts was very warm and near instant throughout the experience, which took a lot of stress off of the trip. <br/>Kudos to the team, I enjoyed my stay and will be back. <br/>Thanks again!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-30T20:17:18Z",
#         "rating": 5,
#         "guest_name": "Zack",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Great place and in a great location. Would definitely stay again",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-19T21:43:34Z",
#         "rating": 5,
#         "guest_name": "Sungano",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "10 years on Airbnb",
#         "review": "Pros... there are many:<br/>Best thing about this place is the full view of the city from both the lounge and the bedroom - I couldn't get enough of it!<br/>Place is much as pictured, photos are glossier and make it seem a bit bigger/ brighter. It's still a beautiful place, even without the gloss.<br/>Check in was simple and contactless.<br/>Everything was clean<br/>Appreciated the Tim Hortons coffee pods every morning :)<br/>Nice Japanese restaurant/ bento place nearby, and a convenient walk/ ride to Stephen Avenue. <br/>Bed was very comfy, and there's loads of storage space.<br/>-Shower head - please replace asap as that one is unusable - used the bottom tap which was frustrating.<br/>- Soap dispenser - pump did not work throughout my stay<br/>- Some sockets in bedroom don't work<br/>- Not a major issue for me, but  bedroom closet door is broken and leans on a wall<br/>-Communication was prompt, except near check-out; requested delayed check out and had to follow up next day. Declined, so had to leave sharpish!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-14T22:22:52Z",
#         "rating": 5,
#         "guest_name": "Daniel",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Place was wonderful. Right in downtown Calgary with amazing views of the city. Place was clean and tidy. I would definitely comeback!!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-03T20:22:31Z",
#         "rating": 5,
#         "guest_name": "Austin",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "6 years on Airbnb",
#         "review": "Pool area was a little underwhelming. Barely got any sun amd was undersized- no one uses this space but it has potential",
#         "host_response": null
#       },
#       {
#         "review_date": "2024-12-21T21:16:25Z",
#         "rating": 5,
#         "guest_name": "Mitch",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Overall great place, it is common for elevator maintenance and operation to fluctuate affecting lift times, but other than that the space was clean, ready on-time, and cozy in the evenings. The team was available via messages 24/7. Would stay here again!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-05T21:41:02Z",
#         "rating": 5,
#         "guest_name": "Reem",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Toronto, Canada",
#         "review": "Nice place. Location is great, good view, smooth check in.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-30T20:50:57Z",
#         "rating": 5,
#         "guest_name": "Marianna",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Definitely will stay again! Apartment have perfect view from the balcony and we liked it so much!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-21T21:37:05Z",
#         "rating": 5,
#         "guest_name": "Colby Staurt",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Medicine Hat, Canada",
#         "review": "Really nice place definitely gonna come again",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-17T21:32:44Z",
#         "rating": 5,
#         "guest_name": "Brad",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Langley, Canada",
#         "review": "It was pretty chill and easy to get to",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-13T20:09:23Z",
#         "rating": 5,
#         "guest_name": "Tylor",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "5 years on Airbnb",
#         "review": "Great views of the city!!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-20T21:25:28Z",
#         "rating": 5,
#         "guest_name": "Tin",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Vancouver, Canada",
#         "review": "Good location, place has nice views and pretty spacious!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-07T22:53:50Z",
#         "rating": 5,
#         "guest_name": "Brody",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Calgary, Canada",
#         "review": "The place was in good shape, and had a great view!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-05-11T22:39:35Z",
#         "rating": 5,
#         "guest_name": "Issiel",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Beautiful apartment looked just like the pictures with a great view. Check in process was easy and I would stay here again . The apartment was very clean as well.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-16T19:10:51Z",
#         "rating": 5,
#         "guest_name": "Fady",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Nice view",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-16T22:55:09Z",
#         "rating": 5,
#         "guest_name": "Gjin",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Zurich, Switzerland",
#         "review": "Gute Bars und Restaurants in Laufdistanz. Check-In und Out war einfach und unkompliziert. Tolle Aussicht vom Balkon, besonders am Abend. Bei Fragen haben sie schnell reagiert.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-02T21:02:06Z",
#         "rating": 5,
#         "guest_name": "Benjamin",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Paris, France",
#         "review": "love it",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-18T22:07:20Z",
#         "rating": 5,
#         "guest_name": "Tylor",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "5 years on Airbnb",
#         "review": "Good stay",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-10T22:34:45Z",
#         "rating": 4,
#         "guest_name": "Juan De Dios",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "A few things were downsides but overall 9/10",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-08T21:36:41Z",
#         "rating": 5,
#         "guest_name": "Alyssa",
#         "stayed_for": "Stayed about a week",
#         "guest_time_on_airbnb": "4 months on Airbnb",
#         "review": "Amazing time, no complaints would stay again ✨",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-29T20:35:17Z",
#         "rating": 5,
#         "guest_name": "Dillon",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Thunder Bay, Canada",
#         "review": "Great place to stay with a nice view of the city.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-05-27T21:29:14Z",
#         "rating": 5,
#         "guest_name": "Trev",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Calgary, Canada",
#         "review": "amazing view",
#         "host_response": null
#       }
#     ],
#     "timestamp": "2025-11-10T00:26:57.580Z"
#   }
# ]

# %%
out_path = "pretty_airbnb_data.json"
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)
print("Saved pretty JSON to", out_path)
# Out:
# Saved pretty JSON to pretty_airbnb_data.json

# %% [markdown]
# # Data by URL

# %%
url = "https://api.brightdata.com/datasets/v3/trigger"
headers = {
        "Authorization": f"Bearer {brightdata_api_key}",
        "Content-Type": "application/json",
}
params = {
        "dataset_id": "gd_ld7ll037kqy322v05",
}

data = {
    "input": [
        {"url": "https://www.airbnb.ca/rooms/1300059188064308611", "country": "CA"}
    ],
    "custom_output_fields": [
        "name",
        "price",
        # "image",
        "description",
        "category",
        "availability",
        "discount",
        "reviews",
        "ratings",
        # "seller_info",
        # "breadcrumbs",
        "location",
        "lat",
        "long",
        "guests",
        "pets_allowed",
        "description_items",
        "category_rating",
        "house_rules",
        "details",
        "highlights",
        "arrangement_details",
        "amenities",
        # "images",
        # "available_dates",
        "url",
        # "final_url",
        "listing_title",
        "property_id",
        "listing_name",
        "location_details",
        "description_by_sections",
        # "description_html",
        # "location_details_html",
        "is_supperhost",
        "host_number_of_reviews",
        "host_rating",
        "hosts_year",
        "host_response_rate",
        "is_guest_favorite",
        "travel_details",
        "pricing_details",
        "total_price",
        "currency",
        "cancellation_policy",
        "property_number_of_reviews",
        # "country",
        # "postcode_map_url",
        # "host_image",
        "host_details",
        "reviews_details",
        "timestamp",
        # "input",
        # "discovery_input",
        # "error",
        # "error_code",
        # "warning",
        # "warning_code"
    ],
}

response = requests.post(url, headers=headers, params=params, json=data)
print(response.json())
# Out:
# {'snapshot_id': 's_mhtpiqdf1lf1u1nr4c'}

# %%
import requests
import json

url = "https://api.brightdata.com/datasets/v3/snapshot/s_mhtpiqdf1lf1u1nr4c"
headers = {
    "Authorization": f"Bearer {brightdata_api_key}",
}
params = {"format": "json"}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# Pretty-print entire JSON to console
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "name": "Rental unit in Calgary · ★4.82 · 2 bedrooms · 3 beds · 1 bath",
#     "price": 153.08,
#     "description": "Welcome to our 2-bed home in the heart of the Beltline! The dining area comfortably seats 6, perfect for gatherings. The primary bedroom features a super comfy King bed, while the secondary offers a cozy Queen. Need more space? A queen pull-out couch adds flexibility.Enjoy in-suite laundry and a fully stocked kitchen. Building amenities include a Gym and a Rooftop Patio with downtown views. Just 3 blocks off 17th Ave, this unit offers unbeatable walkability to shops, dining, and entertainment!The spaceDiscover ultimate comfort and style in this beautifully designed 2-bedroom condo, offering everything you need for a relaxing stay:Bright & Open:-Sunlit south-facing balcony to enjoy natural light-Spacious dining table for 6, plus extra seating at the kitchen islandWork-Friendly:-Dedicated workspace with high-speed internet, printer, monitor, keyboard, and mouseCozy Bedrooms:-Primary room with a SUPER COMFY king-sized bed and generous closet space-Secondary room with a comfortable queen bed-Queen-sized pull-out couch for additional guestsWell-Equipped Bathroom:-Soft face, hand, and bath towels-Stocked with shampoo, conditioner, and body washFully Loaded Kitchen:-Features a blender, coffee maker, toaster, hot water kettle, and baking tools-Keurig machine with complimentary coffee pods for your morningsAdded Convenience:-58\" Smart TV-In Unit laundry room Building Amenities:-On-site fitness room-Stunning rooftop patio with panoramic city viewsUnbeatable Location:-Steps from Calgary’s best restaurants, shops, and downtown attractions-Ideal for those seeking a vibrant, walkable lifestyleWith its modern design, thoughtful amenities, and prime location, this condo is the perfect place to call home during your stay!Guest accessYou will have access to the entire Condo during your stay.Other things to note-Missing keys incur a $250 replacement fee.-Respect condo bylaws, especially quiet hours after 10pm. We use a noise monitoring device; It does NOT record actual sounds or conversations, it simply monitors the noise level (measured in decibels). Minut is 100% privacy compliant and is required on this property. If you have any questions, please ask! :)Registration detailsBL287930",
#     "category": "Stays",
#     "availability": "true",
#     "reviews": [
#       "Nice place in a great area. Parking was excellent as spot is 20 steps from your door. Beds were quite comfortable and kitchen was stocked with everything you need. The area is pretty noisy at night but being downtown it should be expected. We really enjoyed our stay and would definitely stay again. Thank you Tristan",
#       "The location was perfect for our stay. We attended a festival at Cowboy Park which was approximately a 15 min walk from this place. There is a lot of places to eat close by and within walking distance. The parking spot and street parking are both convenient and felt safe. The instructions into the building were a little confusing but we managed. Overall, we would definitely stay again and would recommend the space.",
#       "Tristan’s place is fantastic! Great furnishings and comfortable beds. The location is close to wonderful restaurants and coffeehouses. It is close to lots of things to do yet tucked in a quiet street. The parking stall was very appreciated. Thanks Tristan!",
#       "Great value for money, the apartment was beautiful and had everything you need. Tristan was very responsive and helpful, I’d definitely stay again if I came back to Calgary",
#       "Our stay was wonderful, it’s a nice fancy safe place by the heart of downtown, only 5 minutes from Calgary tower and 5 to 6 minutes away from two downtown mosques in Calgary.",
#       "We had a wonderful stay at Tristan’s place in Calgary! The house was clean, secure, and beautifully maintained. It looked just like the photos, if not better. Tristan was an excellent host, very welcoming and quick to respond to our messages. We truly felt comfortable and well taken care of throughout our stay.<br/>Will definitely recommend this place to all our friends and family in Saskatoon!",
#       "Pros:Great location! Beds were comfy. very little required from us to check out which was appreciated. <br/>Con:Pictures did not meet the actual place (small apartment) The work space is in the living room right next to the only TV, Sofa and access to the balcony. So if one of you is working the other person will have to be in one of the bedrooms.",
#       "Very good spot, very centric.  It has been a good experience. The flat is comfortable and nice. Recommendable.<br/>Unfortunately, there was a fire alarm inspection during our stay. We couldn’t access to the rooftop.<br/>The price is a bit high comparing to other places, but it is true that is in Calgary Downtown and during the summer.",
#       "This place was amazing and the hosts had the two most important qualities I like to see: responsive and friendly. From the property you can get anywhere downtown in about 10 mins driving and there are a ton of things within a 5 to 10 min walk. It is in a safe neighborhood and while we were there it was quiet and peaceful. If you are looking for an affordable clean place to stay with responsive hosts then I recomend!",
#       "Host was very communicative and responsive. Location is awesome and the place was accurately represented in the photos. <br/>**IMPORTANT** This building is VERY strict on noise. We were threatened by a resident at 3 pm in the afternoon because we were playing music and we talked in halls. We felt like we were walking on eggshells for the remainder of our stay. This place is suitable as a landing spot for a quiet group, but I would not recommend if you’re looking for a place that feels like home.",
#       "Had some issues with the check in process due to a miscommunication on the host's part, but apart from that rough start, it was overall a great place (clean, quiet, good location).",
#       "Really loved the location!  Very convenient to 17th Avenue with tons of restaurant options and shopping.  In the other direction, it was a short walk to the Central Library and the incredible murals all over Calgary!",
#       "Tristan was friendly and communicative our whole stay - always reaching out to make sure everything was going okay. :) Great host!",
#       "Great stay, proactive and responsive hosts, everything is exactly same as listed, thanks for hosting us.",
#       "I found Tristan’s place an absolute diamond of a find! It was so secure and private, in a great location walkable to the bustling streets for restaurants and shops. The apartment was pristine and beautifully furnished, the kitchen was kitted out and very well stocked. The owners were so helpful and kind also. Such good value for money and will definitely stay again when I’m back in Calgary. Couldn’t recommend more highly! :)",
#       "Second time staying here. Great location and awesome host. Highly recommended and definitely stay here next time!",
#       "The lodging matched the photos and description. We liked the apartment and the location. The price was very reasonable. We had 5 ppl stay comfortably. My reasons for not giving 5 stars is the fairly unreasonable quiet hours and the manner we were treated by other residents. And the serious amount of door locks and security was at times frustrating. It was hard to get in and out with all the keys fobs locks buttons and doors. If you intend to have a very quiet stay and few occupants this prob would be a great choice. If you wanna hang here and enjoy a few laughs in the middle of the day be prepared for noise disturbance complaints both from residents and an in house monitor system. The host was great and very good communicator. I just would not bring a group here. Beds were ok, but not great. Bathroom and kitchen very nice. Great location in Calgary. Cute place.  I’m sad we never went to the rooftop. We used the parking garage spot which was very convenient.",
#       "Great place to stay in downtown Calgary. Great neighbourhood, close to shops. Highly recommended.",
#       "Great experience! Highly recommend. Beautiful apartment and host was extremely helpful. Wish we stayed longer!",
#       "We booked  staff members in Tristan’s place and they had a wonderful experience.  Very happy with their accommodations and how well Tristan communicated.",
#       "Excellent place to stay in Calgary. Very peaceful area, yet walkable to a ton of places in the area. The apartment was exactly as described, and the parking was great for a Full size F150 truck. The unit matched the pictures and descriptions, and the hosts were excellent.",
#       "nice quiet location. Walking distance to everything I needed - safeway is just around the corner.<br/>I stayed 2 weeks and it was homey.<br/>I loved it so much I am coming back for work for 3 week and booked it again.<br/>Kenzie was a gem to deal with.",
#       "Clean , convenient and good fare pricing",
#       "Very clean and well located place to stay in Calgary."
#     ],
#     "ratings": 4.82,
#     "location": "Calgary, Alberta, Canada",
#     "lat": 51.0403,
#     "long": -114.0802,
#     "guests": 6,
#     "pets_allowed": true,
#     "description_items": [
#       "Entire rental unit",
#       "3 beds",
#       "1 bath"
#     ],
#     "category_rating": [
#       {
#         "name": "Cleanliness",
#         "value": "4.9"
#       },
#       {
#         "name": "Accuracy",
#         "value": "4.9"
#       },
#       {
#         "name": "Check-in",
#         "value": "4.7"
#       },
#       {
#         "name": "Communication",
#         "value": "5.0"
#       },
#       {
#         "name": "Location",
#         "value": "4.9"
#       },
#       {
#         "name": "Value",
#         "value": "4.7"
#       }
#     ],
#     "house_rules": [
#       "Check-in: 3:00 p.m.–9:00 p.m.",
#       "Checkout before 11:00 a.m.",
#       "6 guests maximum"
#     ],
#     "details": [
#       "6 guests",
#       "2 bedrooms",
#       "3 beds",
#       "1 bath"
#     ],
#     "highlights": [
#       {
#         "name": "Self check-in",
#         "value": "Check yourself in with the smartlock."
#       },
#       {
#         "name": "Comfy bed for better sleep",
#         "value": "The room-darkening shades and extra bedding are loved by guests."
#       },
#       {
#         "name": "Great restaurants nearby",
#         "value": "Guests say there are excellent options for dining out."
#       }
#     ],
#     "arrangement_details": [
#       {
#         "name": "Bedroom 1",
#         "value": "1 king bed"
#       },
#       {
#         "name": "Bedroom 2",
#         "value": "1 queen bed"
#       },
#       {
#         "name": "Living room",
#         "value": "1 sofa bed"
#       }
#     ],
#     "amenities": [
#       {
#         "items": [
#           {
#             "value": "SYSTEM_BATHTUB",
#             "name": "Bathtub"
#           },
#           {
#             "value": "SYSTEM_HAIRDRYER",
#             "name": "Hair dryer"
#           },
#           {
#             "value": "SYSTEM_CLEANING_SUPPLIES",
#             "name": "Cleaning products"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Shampoo"
#           },
#           {
#             "value": "SYSTEM_SHAMPOO",
#             "name": "Conditioner"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Body soap"
#           },
#           {
#             "value": "SYSTEM_HOT_WATER",
#             "name": "Hot water"
#           },
#           {
#             "value": "SYSTEM_SOAP",
#             "name": "Shower gel"
#           }
#         ],
#         "group_name": "Bathroom"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_WASHER",
#             "name": "Washer"
#           },
#           {
#             "value": "SYSTEM_DRYER",
#             "name": "Dryer"
#           },
#           {
#             "value": "Towels, bed sheets, soap, and toilet paper",
#             "name": "Essentials"
#           },
#           {
#             "value": "SYSTEM_HANGERS",
#             "name": "Hangers"
#           },
#           {
#             "value": "SYSTEM_BLANKETS",
#             "name": "Bed linens"
#           },
#           {
#             "value": "SYSTEM_PILLOW",
#             "name": "Extra pillows and blankets"
#           },
#           {
#             "value": "SYSTEM_BLACKOUT_SHADES",
#             "name": "Room-darkening shades"
#           },
#           {
#             "value": "SYSTEM_IRON",
#             "name": "Iron"
#           },
#           {
#             "value": "SYSTEM_WARDROBE",
#             "name": "Clothing storage"
#           }
#         ],
#         "group_name": "Bedroom and laundry"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_CABLE",
#             "name": "Ethernet connection"
#           },
#           {
#             "value": "SYSTEM_TV",
#             "name": "TV"
#           }
#         ],
#         "group_name": "Entertainment"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_CHILD_UTENSILS",
#             "name": "Children’s dinnerware"
#           }
#         ],
#         "group_name": "Family"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_THERMOMETER",
#             "name": "Heating"
#           }
#         ],
#         "group_name": "Heating and cooling"
#       },
#       {
#         "items": [
#           {
#             "value": "The monitor is not located in bedrooms, bathrooms, or sleeping areas.",
#             "name": "Noise decibel monitors on property"
#           },
#           {
#             "value": "Security camera built into the smart lock at the main door of the condo, facing outside.",
#             "name": "Exterior security cameras on property"
#           },
#           {
#             "value": "SYSTEM_DETECTOR_SMOKE",
#             "name": "Smoke alarm"
#           },
#           {
#             "value": "SYSTEM_DETECTOR_CO",
#             "name": "Carbon monoxide alarm"
#           },
#           {
#             "value": "SYSTEM_FIRE_EXTINGUISHER",
#             "name": "Fire extinguisher"
#           },
#           {
#             "value": "SYSTEM_FIRST_AID_KIT",
#             "name": "First aid kit"
#           }
#         ],
#         "group_name": "Home safety"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_WI_FI",
#             "name": "Wifi"
#           },
#           {
#             "value": "SYSTEM_WORKSPACE",
#             "name": "Dedicated workspace"
#           }
#         ],
#         "group_name": "Internet and office"
#       },
#       {
#         "items": [
#           {
#             "value": "Space where guests can cook their own meals",
#             "name": "Kitchen"
#           },
#           {
#             "value": "SYSTEM_REFRIGERATOR",
#             "name": "Refrigerator"
#           },
#           {
#             "value": "SYSTEM_MICROWAVE",
#             "name": "Microwave"
#           },
#           {
#             "value": "Pots and pans, oil, salt and pepper",
#             "name": "Cooking basics"
#           },
#           {
#             "value": "Bowls, chopsticks, plates, cups, etc.",
#             "name": "Dishes and silverware"
#           },
#           {
#             "value": "SYSTEM_MINI_BAR",
#             "name": "Mini fridge"
#           },
#           {
#             "value": "SYSTEM_REFRIGERATOR",
#             "name": "Freezer"
#           },
#           {
#             "value": "SYSTEM_DISHWASHER",
#             "name": "Dishwasher"
#           },
#           {
#             "value": "SYSTEM_STOVE",
#             "name": "Stove"
#           },
#           {
#             "value": "SYSTEM_OVEN",
#             "name": "Oven"
#           },
#           {
#             "value": "SYSTEM_WATER_KETTLE",
#             "name": "Hot water kettle"
#           },
#           {
#             "value": "SYSTEM_COFFEE_MAKER",
#             "name": "Coffee maker: Keurig coffee machine"
#           },
#           {
#             "value": "SYSTEM_MAPS_BAR",
#             "name": "Wine glasses"
#           },
#           {
#             "value": "SYSTEM_TOASTER",
#             "name": "Toaster"
#           },
#           {
#             "value": "SYSTEM_BAKING_SHEET",
#             "name": "Baking sheet"
#           },
#           {
#             "value": "SYSTEM_BLENDER",
#             "name": "Blender"
#           },
#           {
#             "value": "SYSTEM_DINING_TABLE",
#             "name": "Dining table"
#           },
#           {
#             "value": "SYSTEM_COFFEE_MAKER",
#             "name": "Coffee"
#           }
#         ],
#         "group_name": "Kitchen and dining"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_LAUNDRY_SERVICE",
#             "name": "Laundromat nearby"
#           }
#         ],
#         "group_name": "Location features"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_PATIO_BALCONY",
#             "name": "Patio or balcony"
#           },
#           {
#             "value": "SYSTEM_ROOFTOP_DECK",
#             "name": "Outdoor furniture"
#           }
#         ],
#         "group_name": "Outdoor"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_MAPS_CAR_RENTAL",
#             "name": "Free parking on premises"
#           },
#           {
#             "value": "The home or building has an elevator that’s at least 52 inches deep and a doorway at least 32 inches wide",
#             "name": "Elevator"
#           },
#           {
#             "value": "SYSTEM_GYM",
#             "name": "Gym"
#           }
#         ],
#         "group_name": "Parking and facilities"
#       },
#       {
#         "items": [
#           {
#             "value": "Assistance animals are always allowed",
#             "name": "Pets allowed"
#           },
#           {
#             "value": "Allow stay for 28 days or more",
#             "name": "Long-term stays allowed"
#           },
#           {
#             "value": "SYSTEM_KEY",
#             "name": "Self check-in"
#           },
#           {
#             "value": "SYSTEM_LOCK_ON_DOOR",
#             "name": "Smart lock"
#           },
#           {
#             "value": "SYSTEM_CLEAN",
#             "name": "Housekeeping - available at extra cost"
#           }
#         ],
#         "group_name": "Services"
#       },
#       {
#         "items": [
#           {
#             "value": "SYSTEM_NO_AIR_CONDITIONING",
#             "name": "Air conditioning"
#           },
#           {
#             "value": "SYSTEM_NO_PRIVATE_ENTRANCE",
#             "name": "Private entrance"
#           }
#         ],
#         "group_name": "Not included"
#       }
#     ],
#     "url": "https://www.airbnb.ca/rooms/1300059188064308611",
#     "listing_title": "Stylish Downtown Getaway | Parking & GYM!",
#     "property_id": "1300059188064308611",
#     "listing_name": "Entire rental unit in Calgary, Canada",
#     "location_details": [
#       {
#         "title": "Neighbourhood highlights",
#         "value": "This condo is located in the heart of Calgary's Beltline and only a few blocks away from the city's best restaurants, shops, and attractions!"
#       },
#       {
#         "title": "Getting around",
#         "value": "You will have access to your own parking stall in the buildings secure parkade. The unit is located very centrally and a quick commute to anywhere you have to go!"
#       }
#     ],
#     "description_by_sections": [
#       {
#         "title": null,
#         "value": "Welcome to our 2-bed home in the heart of the Beltline! The dining area comfortably seats 6, perfect for gatherings. The primary bedroom features a super comfy King bed, while the secondary offers a cozy Queen. Need more space? A queen pull-out couch adds flexibility.Enjoy in-suite laundry and a fully stocked kitchen. Building amenities include a Gym and a Rooftop Patio with downtown views. Just 3 blocks off 17th Ave, this unit offers unbeatable walkability to shops, dining, and entertainment!"
#       },
#       {
#         "title": "The space",
#         "value": "Discover ultimate comfort and style in this beautifully designed 2-bedroom condo, offering everything you need for a relaxing stay:Bright & Open:-Sunlit south-facing balcony to enjoy natural light-Spacious dining table for 6, plus extra seating at the kitchen islandWork-Friendly:-Dedicated workspace with high-speed internet, printer, monitor, keyboard, and mouseCozy Bedrooms:-Primary room with a SUPER COMFY king-sized bed and generous closet space-Secondary room with a comfortable queen bed-Queen-sized pull-out couch for additional guestsWell-Equipped Bathroom:-Soft face, hand, and bath towels-Stocked with shampoo, conditioner, and body washFully Loaded Kitchen:-Features a blender, coffee maker, toaster, hot water kettle, and baking tools-Keurig machine with complimentary coffee pods for your morningsAdded Convenience:-58\" Smart TV-In Unit laundry room Building Amenities:-On-site fitness room-Stunning rooftop patio with panoramic city viewsUnbeatable Location:-Steps from Calgary’s best restaurants, shops, and downtown attractions-Ideal for those seeking a vibrant, walkable lifestyleWith its modern design, thoughtful amenities, and prime location, this condo is the perfect place to call home during your stay!"
#       },
#       {
#         "title": "Guest access",
#         "value": "You will have access to the entire Condo during your stay."
#       },
#       {
#         "title": "Other things to note",
#         "value": "-Missing keys incur a $250 replacement fee.-Respect condo bylaws, especially quiet hours after 10pm. We use a noise monitoring device; It does NOT record actual sounds or conversations, it simply monitors the noise level (measured in decibels). Minut is 100% privacy compliant and is required on this property. If you have any questions, please ask! :)"
#       },
#       {
#         "title": "Registration details",
#         "value": "BL287930"
#       }
#     ],
#     "is_supperhost": true,
#     "host_number_of_reviews": 1917,
#     "host_rating": 4.89,
#     "hosts_year": 3,
#     "host_response_rate": 99,
#     "is_guest_favorite": false,
#     "travel_details": {
#       "check_in": null,
#       "check_out": null,
#       "num_of_adults": null,
#       "num_of_children": null,
#       "num_of_infants": null,
#       "num_of_pets": null
#     },
#     "pricing_details": {
#       "num_of_nights": 3,
#       "initial_price_per_night": 153.08,
#       "price_per_night": 153.08,
#       "price_without_fees": 459.24,
#       "special_offer": null,
#       "cleaning_fee": null,
#       "airbnb_service_fee": null,
#       "taxes": null
#     },
#     "total_price": 500.57,
#     "currency": "USD",
#     "cancellation_policy": [
#       {
#         "cancellation_name": "Full refund",
#         "cancellation_value": "12/06/2025"
#       },
#       {
#         "cancellation_name": "Partial refund",
#         "cancellation_value": "12/13/2025"
#       },
#       {
#         "cancellation_name": "No refund",
#         "cancellation_value": "12/13/2025"
#       }
#     ],
#     "property_number_of_reviews": 51,
#     "host_details": {
#       "name": "Tristan",
#       "host_id": "52251080",
#       "url": "https://www.airbnb.com/users/show/52251080",
#       "image": "https://a0.muscache.com/im/pictures/user/1c9bf2f8-4deb-4723-b0c7-d6be080dbd49.jpg",
#       "reviews": 1917,
#       "rating": 4.89,
#       "years_hosting": 3,
#       "response_rate": "Response rate: 99%",
#       "response_time": "Responds within an hour",
#       "my_work": "Real Estate Agent",
#       "languages": null
#     },
#     "reviews_details": [
#       {
#         "review_date": "2025-09-29T21:07:33Z",
#         "rating": 5,
#         "guest_name": "Kevin",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Medicine Hat, Canada",
#         "review": "Nice place in a great area. Parking was excellent as spot is 20 steps from your door. Beds were quite comfortable and kitchen was stocked with everything you need. The area is pretty noisy at night but being downtown it should be expected. We really enjoyed our stay and would definitely stay again. Thank you Tristan",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-17T20:30:20Z",
#         "rating": 5,
#         "guest_name": "Katie",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "North Vancouver, Canada",
#         "review": "The location was perfect for our stay. We attended a festival at Cowboy Park which was approximately a 15 min walk from this place. There is a lot of places to eat close by and within walking distance. The parking spot and street parking are both convenient and felt safe. The instructions into the building were a little confusing but we managed. Overall, we would definitely stay again and would recommend the space.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-05T21:07:10Z",
#         "rating": 5,
#         "guest_name": "Shawn",
#         "stayed_for": "Stayed with kids",
#         "guest_time_on_airbnb": "Lethbridge, Canada",
#         "review": "Tristan’s place is fantastic! Great furnishings and comfortable beds. The location is close to wonderful restaurants and coffeehouses. It is close to lots of things to do yet tucked in a quiet street. The parking stall was very appreciated. Thanks Tristan!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-17T20:53:29Z",
#         "rating": 5,
#         "guest_name": "Alannah",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "1 month on Airbnb",
#         "review": "Great value for money, the apartment was beautiful and had everything you need. Tristan was very responsive and helpful, I’d definitely stay again if I came back to Calgary",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-19T22:01:23Z",
#         "rating": 5,
#         "guest_name": "Ahmad",
#         "stayed_for": "Stayed with kids",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Our stay was wonderful, it’s a nice fancy safe place by the heart of downtown, only 5 minutes from Calgary tower and 5 to 6 minutes away from two downtown mosques in Calgary.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-23T19:02:22Z",
#         "rating": 5,
#         "guest_name": "Analiza",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "4 years on Airbnb",
#         "review": "We had a wonderful stay at Tristan’s place in Calgary! The house was clean, secure, and beautifully maintained. It looked just like the photos, if not better. Tristan was an excellent host, very welcoming and quick to respond to our messages. We truly felt comfortable and well taken care of throughout our stay.<br/>Will definitely recommend this place to all our friends and family in Saskatoon!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-18T19:12:44Z",
#         "rating": 4,
#         "guest_name": "Zoya",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Phoenix, Arizona",
#         "review": "Pros:Great location! Beds were comfy. very little required from us to check out which was appreciated. <br/>Con:Pictures did not meet the actual place (small apartment) The work space is in the living room right next to the only TV, Sofa and access to the balcony. So if one of you is working the other person will have to be in one of the bedrooms.",
#         "host_response": "Hi Zoya,<br/>In our listing photos, pictures show quite clearly that the desk is in the living room so I am sorry this was unexpected to you. We like to include a workspace where we can, and that was the space that worked. Our photos depict the space pretty accurately."
#       },
#       {
#         "review_date": "2025-06-29T21:04:48Z",
#         "rating": 4,
#         "guest_name": "Reyes",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "7 years on Airbnb",
#         "review": "Very good spot, very centric.  It has been a good experience. The flat is comfortable and nice. Recommendable.<br/>Unfortunately, there was a fire alarm inspection during our stay. We couldn’t access to the rooftop.<br/>The price is a bit high comparing to other places, but it is true that is in Calgary Downtown and during the summer.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-18T19:14:00Z",
#         "rating": 5,
#         "guest_name": "Jared",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Meridian, Idaho",
#         "review": "This place was amazing and the hosts had the two most important qualities I like to see: responsive and friendly. From the property you can get anywhere downtown in about 10 mins driving and there are a ton of things within a 5 to 10 min walk. It is in a safe neighborhood and while we were there it was quiet and peaceful. If you are looking for an affordable clean place to stay with responsive hosts then I recomend!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-08-04T20:25:20Z",
#         "rating": 4,
#         "guest_name": "Leah",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "Toronto, Canada",
#         "review": "Host was very communicative and responsive. Location is awesome and the place was accurately represented in the photos. <br/>**IMPORTANT** This building is VERY strict on noise. We were threatened by a resident at 3 pm in the afternoon because we were playing music and we talked in halls. We felt like we were walking on eggshells for the remainder of our stay. This place is suitable as a landing spot for a quiet group, but I would not recommend if you’re looking for a place that feels like home.",
#         "host_response": "Hi Leah, I apologize you were affected by one neighbours actions. These do not reflect the building as a whole, and definitely not us as hosts either. We have normal building quiet hours, but it’s unfortunate the one encounter garnered a negative review here."
#       },
#       {
#         "review_date": "2025-06-21T21:39:37Z",
#         "rating": 4,
#         "guest_name": "Julien",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "Ottawa, Canada",
#         "review": "Had some issues with the check in process due to a miscommunication on the host's part, but apart from that rough start, it was overall a great place (clean, quiet, good location).",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-05-29T19:25:16Z",
#         "rating": 5,
#         "guest_name": "Brad",
#         "stayed_for": "Stayed with a pet",
#         "guest_time_on_airbnb": "Portland, Oregon",
#         "review": "Really loved the location!  Very convenient to 17th Avenue with tons of restaurant options and shopping.  In the other direction, it was a short walk to the Central Library and the incredible murals all over Calgary!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-15T20:37:16Z",
#         "rating": 5,
#         "guest_name": "Sagiri",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "Niagara Falls, Canada",
#         "review": "Tristan was friendly and communicative our whole stay - always reaching out to make sure everything was going okay. :) Great host!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-07T19:16:31Z",
#         "rating": 5,
#         "guest_name": "Erkut",
#         "stayed_for": "Stayed about a week",
#         "guest_time_on_airbnb": "Lincolnshire, Illinois",
#         "review": "Great stay, proactive and responsive hosts, everything is exactly same as listed, thanks for hosting us.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-04-28T21:43:23Z",
#         "rating": 5,
#         "guest_name": "Alison",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "7 years on Airbnb",
#         "review": "I found Tristan’s place an absolute diamond of a find! It was so secure and private, in a great location walkable to the bustling streets for restaurants and shops. The apartment was pristine and beautifully furnished, the kitchen was kitted out and very well stocked. The owners were so helpful and kind also. Such good value for money and will definitely stay again when I’m back in Calgary. Couldn’t recommend more highly! :)",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-10-30T19:59:03Z",
#         "rating": 5,
#         "guest_name": "Jason",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "Second time staying here. Great location and awesome host. Highly recommended and definitely stay here next time!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-11T20:21:21Z",
#         "rating": 4,
#         "guest_name": "Mary",
#         "stayed_for": null,
#         "guest_time_on_airbnb": "Warrenton, Virginia",
#         "review": "The lodging matched the photos and description. We liked the apartment and the location. The price was very reasonable. We had 5 ppl stay comfortably. My reasons for not giving 5 stars is the fairly unreasonable quiet hours and the manner we were treated by other residents. And the serious amount of door locks and security was at times frustrating. It was hard to get in and out with all the keys fobs locks buttons and doors. If you intend to have a very quiet stay and few occupants this prob would be a great choice. If you wanna hang here and enjoy a few laughs in the middle of the day be prepared for noise disturbance complaints both from residents and an in house monitor system. The host was great and very good communicator. I just would not bring a group here. Beds were ok, but not great. Bathroom and kitchen very nice. Great location in Calgary. Cute place.  I’m sad we never went to the rooftop. We used the parking garage spot which was very convenient.",
#         "host_response": "Thank you for your thoughtful review and for choosing to stay with us! We’re so glad to hear you enjoyed the apartment, appreciated the location, and found the parking convenient. It’s great to know the space comfortably accommodated your group and that communication was smooth throughout your stay.<br/>We did want to kindly clarify a few points for future guests:<br/>- The noise monitoring system is designed to only alert us of prolonged elevated noise levels, not brief or typical sounds of enjoyment.<br/>- Quiet hours begin at 9 PM on weekdays, which is just one hour earlier than Calgary’s bylaw, and are in place to maintain a respectful environment for all residents.<br/>- We’ve also recently streamlined our check-in process, reducing the number of steps and making it easier to navigate the building.<br/>We appreciate your feedback and are always looking for ways to improve. Thanks again for staying with us and for your honest insights!"
#       },
#       {
#         "review_date": "2025-07-03T21:11:15Z",
#         "rating": 5,
#         "guest_name": "Nancy",
#         "stayed_for": "Stayed with kids",
#         "guest_time_on_airbnb": "Regina, Canada",
#         "review": "Great place to stay in downtown Calgary. Great neighbourhood, close to shops. Highly recommended.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-07-01T19:27:00Z",
#         "rating": 5,
#         "guest_name": "Angie",
#         "stayed_for": "Stayed with kids",
#         "guest_time_on_airbnb": "Canada",
#         "review": "Great experience! Highly recommend. Beautiful apartment and host was extremely helpful. Wish we stayed longer!",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-06-13T22:05:40Z",
#         "rating": 5,
#         "guest_name": "Jessica",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Edmonton, Canada",
#         "review": "We booked  staff members in Tristan’s place and they had a wonderful experience.  Very happy with their accommodations and how well Tristan communicated.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-03-02T22:03:08Z",
#         "rating": 5,
#         "guest_name": "Kevin",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Toronto, Canada",
#         "review": "Excellent place to stay in Calgary. Very peaceful area, yet walkable to a ton of places in the area. The apartment was exactly as described, and the parking was great for a Full size F150 truck. The unit matched the pictures and descriptions, and the hosts were excellent.",
#         "host_response": null
#       },
#       {
#         "review_date": "2024-12-21T20:46:38Z",
#         "rating": 5,
#         "guest_name": "Yasmina",
#         "stayed_for": "Stayed over a week",
#         "guest_time_on_airbnb": "Sherwood Park, Canada",
#         "review": "nice quiet location. Walking distance to everything I needed - safeway is just around the corner.<br/>I stayed 2 weeks and it was homey.<br/>I loved it so much I am coming back for work for 3 week and booked it again.<br/>Kenzie was a gem to deal with.",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-21T20:30:35Z",
#         "rating": 5,
#         "guest_name": "Devon",
#         "stayed_for": "Stayed a few nights",
#         "guest_time_on_airbnb": "Kaslo, Canada",
#         "review": "Clean , convenient and good fare pricing",
#         "host_response": null
#       },
#       {
#         "review_date": "2025-09-19T22:17:11Z",
#         "rating": 5,
#         "guest_name": "Justin",
#         "stayed_for": "Stayed one night",
#         "guest_time_on_airbnb": "Montreal, Canada",
#         "review": "Very clean and well located place to stay in Calgary.",
#         "host_response": null
#       }
#     ],
#     "timestamp": "2025-11-10T22:22:44.858Z"
#   }
# ]
